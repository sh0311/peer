# %%
import pickle # 객체 입출력을 위한 라이브러리
from sklearn.model_selection import train_test_split # 훈련 데이터, 테스트 데이터 분리
from sklearn.preprocessing import StandardScaler # 정규화
from sklearn.ensemble import RandomForestClassifier # 랜덤포레스트 분류 알고리즘
import pandas as pd
#from sklearn.decomposition import PCA

# 모델 평가를 위한 metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

# %%
# monitored label=0~95 / unmonitored label=-1로 한 dataset 불러오기
multi=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/open_multi.csv")
multi.head()
# Out:
#    N_in_packets  N_out_packets  in_first_thirty  out_first_thirty  \
# 0          1300            121               21                 9
# 1           438             80               22                 8
# 2          1240            118               23                 7
# 3          1324            122               21                 9
# 4          1291            115               22                 8
#
#    out_fraction  in_fraction     out_std      in_std    out_mean     in_mean  \
# 0      0.085151     0.914849  398.486335  515.483953  705.106154  774.322314
# 1      0.154440     0.845560  150.591146  139.231951  265.406393  227.162500
# 2      0.086892     0.913108  381.878642  472.735508  669.259677  787.110169
# 3      0.084371     0.915629  406.205288  513.916038  714.503021  821.139344
# 4      0.081792     0.918208  395.028889  503.993490  695.740511  790.608696
#
#    N_packets  time_fraction       sum_N  y
# 0       1421         2842.0  140.138067  0
# 1        518         1036.0   50.984252  0
# 2       1358         2716.0  122.232223  0
# 3       1446         2892.0  108.233533  0
# 4       1406         2812.0  132.142857  0

# %%
# 정답값 아닌 애들 분리
X= multi.drop('y', axis=1)
# 목표변수 분리(정답값. 어느 클래스 label에 해당하는지 해당 열)
y = multi['y']

# %%
# train, test 데이터 분리

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size = 0.3, random_state = 1)

# 데이터 스케일링(normalize data)

# 표준 스케일러(평균 0, 분산 1)
#scaler = StandardScaler()
#X_train= scaler.fit_transform(X_train)
#X_test= scaler.fit_transform(X_test)

# %%
# PCA를 사용하여 데이터 차원 축소
#n_components = 0  # 상황에 따라 조절
#pca = PCA(n_components=n_components)
#X_train = pca.fit_transform(X_train)
#X_test = pca.transform(X_test)

# %%
#def k_fingerprinting_classification(model, X_test, k):
    # k 개의 가장 가까운 이웃으로 분류
   # y_pred_k = model.predict(X_test[:, :k])
   # return y_pred_k

# %%
# Perform PCA for dimensionality reduction
#pca = PCA(n_components=0.8)  # You can experiment with different values
#X_train = pca.fit_transform(X_train)
#X_test = pca.transform(X_test)

# %%
clf2 = RandomForestClassifier(n_estimators=150, criterion="gini", max_depth=20, min_samples_split=2, min_samples_leaf=1, random_state=0)
clf2.fit(X_train, y_train)
y_pred = clf2.predict(X_test)
acc = accuracy_score(y_test, y_pred)
print('accuracy_score : ',acc)
# Out:
# accuracy_score :  0.8418390804597701

# %%
# GridSearch로 최적의 하이퍼 파라미터 튜닝

from sklearn.model_selection import GridSearchCV

params = {'n_estimators' : [100, 150, 200],
          'max_depth' : [30, 50, 70],
          'min_samples_leaf' : [1, 2, 4, 6],
          'min_samples_split' : [2, 4, 6],
          #'criterion' : ['gini', 'entropy']
          }


# RandomForestClassifier 객체 생성 후 GridSearchCV 수행
rf_clf = RandomForestClassifier(random_state = 221, n_jobs = -1)
grid = GridSearchCV(rf_clf, params, cv=3, refit = True, verbose = 3)
grid.fit(X_train, y_train)

print('최적 하이퍼 파라미터: ', grid.best_params_)
# Out:
# Fitting 3 folds for each of 108 candidates, totalling 324 fits
# [CV 1/3] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.831 total time=   8.9s
# [CV 2/3] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.833 total time=   6.5s
# [CV 3/3] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.828 total time=   5.4s
# [CV 1/3] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.831 total time=  11.7s
# [CV 2/3] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.835 total time=   9.5s
# [CV 3/3] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.828 total time=  12.6s
# [CV 1/3] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.831 total time=  15.5s
# [CV 2/3] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.835 total time=  14.5s
# [CV 3/3] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.828 total time=  13.0s
# [CV 1/3] END max_depth=30, min_samples_leaf=1, min_samples_split=4, n_estimators=100;, score=0.827 total time=   6.6s
# [CV 2/3] END max_depth=30, min_samples_leaf=1, min_samples_split=4, n_estimators=100;, score=0.832 total time=   5.4s
# [CV 3/3] END max_depth=30, min_samples_leaf=1, min_samples_split=4, n_estimators=100;, score=0.827 total time=   8.3s
# [CV 1/3] END max_depth=30, min_samples_leaf=1, min_samples_split=4, n_estimators=150;, score=0.827 total time=   8.3s
# [CV 2/3] END max_depth=30, min_samples_leaf=1, min_samples_split=4, n_estimators=150;, score=0.835 total time=  11.5s
# [CV 3/3] END max_depth=30, min_samples_leaf=1, min_samples_split=4, n_estimators=150;, score=0.829 total time=   7.9s
# [CV 1/3] END max_depth=30, min_samples_leaf=1, min_samples_split=4, n_estimators=200;, score=0.827 total time=  14.1s
# [CV 2/3] END max_depth=30, min_samples_leaf=1, min_samples_split=4, n_estimators=200;, score=0.834 total time=  14.1s
# [CV 3/3] END max_depth=30, min_samples_leaf=1, min_samples_split=4, n_estimators=200;, score=0.829 total time=  12.0s
# [CV 1/3] END max_depth=30, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.819 total time=   7.1s
# [CV 2/3] END max_depth=30, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.828 total time=   5.2s
# [CV 3/3] END max_depth=30, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.820 total time=   7.7s
# [CV 1/3] END max_depth=30, min_samples_leaf=1, min_samples_split=6, n_estimators=150;, score=0.821 total time=   8.7s
# [CV 2/3] END max_depth=30, min_samples_leaf=1, min_samples_split=6, n_estimators=150;, score=0.826 total time=  11.1s
# [CV 3/3] END max_depth=30, min_samples_leaf=1, min_samples_split=6, n_estimators=150;, score=0.823 total time=   7.9s
# [CV 1/3] END max_depth=30, min_samples_leaf=1, min_samples_split=6, n_estimators=200;, score=0.821 total time=  13.9s
# [CV 2/3] END max_depth=30, min_samples_leaf=1, min_samples_split=6, n_estimators=200;, score=0.827 total time=  13.6s
# [CV 3/3] END max_depth=30, min_samples_leaf=1, min_samples_split=6, n_estimators=200;, score=0.825 total time=  10.5s
# [CV 1/3] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.821 total time=   8.5s
# [CV 2/3] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.828 total time=   5.1s
# [CV 3/3] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.822 total time=   6.1s
# [CV 1/3] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=0.821 total time=  10.1s
# [CV 2/3] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=0.828 total time=   9.6s
# [CV 3/3] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=0.822 total time=   9.2s
# [CV 1/3] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.822 total time=  13.7s
# [CV 2/3] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.827 total time=  11.5s
# [CV 3/3] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.823 total time=  12.3s
# [CV 1/3] END max_depth=30, min_samples_leaf=2, min_samples_split=4, n_estimators=100;, score=0.821 total time=   7.3s
# [CV 2/3] END max_depth=30, min_samples_leaf=2, min_samples_split=4, n_estimators=100;, score=0.828 total time=   6.4s
# [CV 3/3] END max_depth=30, min_samples_leaf=2, min_samples_split=4, n_estimators=100;, score=0.822 total time=   5.1s
# [CV 1/3] END max_depth=30, min_samples_leaf=2, min_samples_split=4, n_estimators=150;, score=0.821 total time=  11.2s
# [CV 2/3] END max_depth=30, min_samples_leaf=2, min_samples_split=4, n_estimators=150;, score=0.828 total time=   7.7s
# [CV 3/3] END max_depth=30, min_samples_leaf=2, min_samples_split=4, n_estimators=150;, score=0.822 total time=  11.1s
# [CV 1/3] END max_depth=30, min_samples_leaf=2, min_samples_split=4, n_estimators=200;, score=0.822 total time=  12.7s
# [CV 2/3] END max_depth=30, min_samples_leaf=2, min_samples_split=4, n_estimators=200;, score=0.827 total time=  15.7s
# [CV 3/3] END max_depth=30, min_samples_leaf=2, min_samples_split=4, n_estimators=200;, score=0.823 total time=  12.5s
# [CV 1/3] END max_depth=30, min_samples_leaf=2, min_samples_split=6, n_estimators=100;, score=0.816 total time=   7.0s
# [CV 2/3] END max_depth=30, min_samples_leaf=2, min_samples_split=6, n_estimators=100;, score=0.820 total time=   6.6s
# [CV 3/3] END max_depth=30, min_samples_leaf=2, min_samples_split=6, n_estimators=100;, score=0.819 total time=   5.1s
# [CV 1/3] END max_depth=30, min_samples_leaf=2, min_samples_split=6, n_estimators=150;, score=0.816 total time=  11.1s
# [CV 2/3] END max_depth=30, min_samples_leaf=2, min_samples_split=6, n_estimators=150;, score=0.822 total time=   7.6s
# [CV 3/3] END max_depth=30, min_samples_leaf=2, min_samples_split=6, n_estimators=150;, score=0.819 total time=  11.1s
# [CV 1/3] END max_depth=30, min_samples_leaf=2, min_samples_split=6, n_estimators=200;, score=0.816 total time=  11.8s
# [CV 2/3] END max_depth=30, min_samples_leaf=2, min_samples_split=6, n_estimators=200;, score=0.824 total time=  11.9s
# [CV 3/3] END max_depth=30, min_samples_leaf=2, min_samples_split=6, n_estimators=200;, score=0.820 total time=  13.6s
# [CV 1/3] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.804 total time=   4.7s
# [CV 2/3] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.809 total time=   7.3s
# [CV 3/3] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.804 total time=   5.7s
# [CV 1/3] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=150;, score=0.805 total time=   7.6s
# [CV 2/3] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=150;, score=0.808 total time=  10.1s
# [CV 3/3] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=150;, score=0.808 total time=   7.6s
# [CV 1/3] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=0.804 total time=  12.4s
# [CV 2/3] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=0.809 total time=  13.0s
# [CV 3/3] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=0.807 total time=   9.7s
# [CV 1/3] END max_depth=30, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.804 total time=   7.9s
# [CV 2/3] END max_depth=30, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.809 total time=   4.8s
# [CV 3/3] END max_depth=30, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.804 total time=   5.1s
# [CV 1/3] END max_depth=30, min_samples_leaf=4, min_samples_split=4, n_estimators=150;, score=0.805 total time=  10.2s
# [CV 2/3] END max_depth=30, min_samples_leaf=4, min_samples_split=4, n_estimators=150;, score=0.808 total time=   7.3s
# [CV 3/3] END max_depth=30, min_samples_leaf=4, min_samples_split=4, n_estimators=150;, score=0.808 total time=  10.4s
# [CV 1/3] END max_depth=30, min_samples_leaf=4, min_samples_split=4, n_estimators=200;, score=0.804 total time=  11.5s
# [CV 2/3] END max_depth=30, min_samples_leaf=4, min_samples_split=4, n_estimators=200;, score=0.809 total time=  10.9s
# [CV 3/3] END max_depth=30, min_samples_leaf=4, min_samples_split=4, n_estimators=200;, score=0.807 total time=  12.9s
# [CV 1/3] END max_depth=30, min_samples_leaf=4, min_samples_split=6, n_estimators=100;, score=0.804 total time=   4.8s
# [CV 2/3] END max_depth=30, min_samples_leaf=4, min_samples_split=6, n_estimators=100;, score=0.809 total time=   6.4s
# [CV 3/3] END max_depth=30, min_samples_leaf=4, min_samples_split=6, n_estimators=100;, score=0.804 total time=   6.5s
# [CV 1/3] END max_depth=30, min_samples_leaf=4, min_samples_split=6, n_estimators=150;, score=0.805 total time=   7.1s
# [CV 2/3] END max_depth=30, min_samples_leaf=4, min_samples_split=6, n_estimators=150;, score=0.808 total time=  10.7s
# [CV 3/3] END max_depth=30, min_samples_leaf=4, min_samples_split=6, n_estimators=150;, score=0.808 total time=   7.1s
# [CV 1/3] END max_depth=30, min_samples_leaf=4, min_samples_split=6, n_estimators=200;, score=0.804 total time=  13.0s
# [CV 2/3] END max_depth=30, min_samples_leaf=4, min_samples_split=6, n_estimators=200;, score=0.809 total time=  12.8s
# [CV 3/3] END max_depth=30, min_samples_leaf=4, min_samples_split=6, n_estimators=200;, score=0.807 total time=   9.6s
# [CV 1/3] END max_depth=30, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.786 total time=   7.8s
# [CV 2/3] END max_depth=30, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.792 total time=   4.8s
# [CV 3/3] END max_depth=30, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.790 total time=   4.6s
# [CV 1/3] END max_depth=30, min_samples_leaf=6, min_samples_split=2, n_estimators=150;, score=0.789 total time=  12.5s
# [CV 2/3] END max_depth=30, min_samples_leaf=6, min_samples_split=2, n_estimators=150;, score=0.793 total time=   8.2s
# [CV 3/3] END max_depth=30, min_samples_leaf=6, min_samples_split=2, n_estimators=150;, score=0.793 total time=   9.9s
# [CV 1/3] END max_depth=30, min_samples_leaf=6, min_samples_split=2, n_estimators=200;, score=0.789 total time=   9.4s
# [CV 2/3] END max_depth=30, min_samples_leaf=6, min_samples_split=2, n_estimators=200;, score=0.792 total time=  12.6s
# [CV 3/3] END max_depth=30, min_samples_leaf=6, min_samples_split=2, n_estimators=200;, score=0.794 total time=  10.8s
# [CV 1/3] END max_depth=30, min_samples_leaf=6, min_samples_split=4, n_estimators=100;, score=0.786 total time=   6.2s
# [CV 2/3] END max_depth=30, min_samples_leaf=6, min_samples_split=4, n_estimators=100;, score=0.792 total time=   4.6s
# [CV 3/3] END max_depth=30, min_samples_leaf=6, min_samples_split=4, n_estimators=100;, score=0.790 total time=   5.8s
# [CV 1/3] END max_depth=30, min_samples_leaf=6, min_samples_split=4, n_estimators=150;, score=0.789 total time=   9.0s
# [CV 2/3] END max_depth=30, min_samples_leaf=6, min_samples_split=4, n_estimators=150;, score=0.793 total time=   7.4s
# [CV 3/3] END max_depth=30, min_samples_leaf=6, min_samples_split=4, n_estimators=150;, score=0.793 total time=   9.6s
# [CV 1/3] END max_depth=30, min_samples_leaf=6, min_samples_split=4, n_estimators=200;, score=0.789 total time=  11.0s
# [CV 2/3] END max_depth=30, min_samples_leaf=6, min_samples_split=4, n_estimators=200;, score=0.792 total time=  11.9s
# [CV 3/3] END max_depth=30, min_samples_leaf=6, min_samples_split=4, n_estimators=200;, score=0.794 total time=  13.3s
# [CV 1/3] END max_depth=30, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.786 total time=   5.1s
# [CV 2/3] END max_depth=30, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.792 total time=   7.1s
# [CV 3/3] END max_depth=30, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.790 total time=   6.1s
# [CV 1/3] END max_depth=30, min_samples_leaf=6, min_samples_split=6, n_estimators=150;, score=0.789 total time=   7.9s
# [CV 2/3] END max_depth=30, min_samples_leaf=6, min_samples_split=6, n_estimators=150;, score=0.793 total time=  10.2s
# [CV 3/3] END max_depth=30, min_samples_leaf=6, min_samples_split=6, n_estimators=150;, score=0.793 total time=   7.2s
# [CV 1/3] END max_depth=30, min_samples_leaf=6, min_samples_split=6, n_estimators=200;, score=0.789 total time=  13.2s
# [CV 2/3] END max_depth=30, min_samples_leaf=6, min_samples_split=6, n_estimators=200;, score=0.792 total time=  12.4s
# [CV 3/3] END max_depth=30, min_samples_leaf=6, min_samples_split=6, n_estimators=200;, score=0.794 total time=   9.6s
# [CV 1/3] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.831 total time=   8.8s
# [CV 2/3] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.836 total time=   5.8s
# [CV 3/3] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.828 total time=   6.5s
# [CV 1/3] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.831 total time=  11.4s
# [CV 2/3] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.834 total time=  10.8s
# [CV 3/3] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.827 total time=   9.6s
# [CV 1/3] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.831 total time=  15.2s
# [CV 2/3] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.834 total time=  15.6s
# [CV 3/3] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.829 total time=  12.3s
# [CV 1/3] END max_depth=50, min_samples_leaf=1, min_samples_split=4, n_estimators=100;, score=0.827 total time=   8.3s
# [CV 2/3] END max_depth=50, min_samples_leaf=1, min_samples_split=4, n_estimators=100;, score=0.831 total time=   5.8s
# [CV 3/3] END max_depth=50, min_samples_leaf=1, min_samples_split=4, n_estimators=100;, score=0.828 total time=   8.7s
# [CV 1/3] END max_depth=50, min_samples_leaf=1, min_samples_split=4, n_estimators=150;, score=0.827 total time=   9.2s
# [CV 2/3] END max_depth=50, min_samples_leaf=1, min_samples_split=4, n_estimators=150;, score=0.834 total time=  12.6s
# [CV 3/3] END max_depth=50, min_samples_leaf=1, min_samples_split=4, n_estimators=150;, score=0.828 total time=   8.5s
# [CV 1/3] END max_depth=50, min_samples_leaf=1, min_samples_split=4, n_estimators=200;, score=0.826 total time=  18.8s
# [CV 2/3] END max_depth=50, min_samples_leaf=1, min_samples_split=4, n_estimators=200;, score=0.833 total time=  13.8s
# [CV 3/3] END max_depth=50, min_samples_leaf=1, min_samples_split=4, n_estimators=200;, score=0.829 total time=  13.3s
# [CV 1/3] END max_depth=50, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.820 total time=   8.3s
# [CV 2/3] END max_depth=50, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.828 total time=   5.5s
# [CV 3/3] END max_depth=50, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.820 total time=   7.6s
# [CV 1/3] END max_depth=50, min_samples_leaf=1, min_samples_split=6, n_estimators=150;, score=0.820 total time=  10.1s
# [CV 2/3] END max_depth=50, min_samples_leaf=1, min_samples_split=6, n_estimators=150;, score=0.826 total time=  10.9s
# [CV 3/3] END max_depth=50, min_samples_leaf=1, min_samples_split=6, n_estimators=150;, score=0.823 total time=   9.4s
# [CV 1/3] END max_depth=50, min_samples_leaf=1, min_samples_split=6, n_estimators=200;, score=0.822 total time=  14.2s
# [CV 2/3] END max_depth=50, min_samples_leaf=1, min_samples_split=6, n_estimators=200;, score=0.827 total time=  14.9s
# [CV 3/3] END max_depth=50, min_samples_leaf=1, min_samples_split=6, n_estimators=200;, score=0.825 total time=  11.2s
# [CV 1/3] END max_depth=50, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.821 total time=   9.5s
# [CV 2/3] END max_depth=50, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.829 total time=   5.6s
# [CV 3/3] END max_depth=50, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.822 total time=   6.5s
# [CV 1/3] END max_depth=50, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=0.822 total time=  10.8s
# [CV 2/3] END max_depth=50, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=0.828 total time=  10.0s
# [CV 3/3] END max_depth=50, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=0.822 total time=   8.8s
# [CV 1/3] END max_depth=50, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.823 total time=  13.8s
# [CV 2/3] END max_depth=50, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.828 total time=  11.9s
# [CV 3/3] END max_depth=50, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.823 total time=  11.9s
# [CV 1/3] END max_depth=50, min_samples_leaf=2, min_samples_split=4, n_estimators=100;, score=0.821 total time=   7.7s
# [CV 2/3] END max_depth=50, min_samples_leaf=2, min_samples_split=4, n_estimators=100;, score=0.829 total time=   6.0s
# [CV 3/3] END max_depth=50, min_samples_leaf=2, min_samples_split=4, n_estimators=100;, score=0.822 total time=   5.2s
# [CV 1/3] END max_depth=50, min_samples_leaf=2, min_samples_split=4, n_estimators=150;, score=0.822 total time=  11.2s
# [CV 2/3] END max_depth=50, min_samples_leaf=2, min_samples_split=4, n_estimators=150;, score=0.828 total time=   7.7s
# [CV 3/3] END max_depth=50, min_samples_leaf=2, min_samples_split=4, n_estimators=150;, score=0.822 total time=  11.2s
# [CV 1/3] END max_depth=50, min_samples_leaf=2, min_samples_split=4, n_estimators=200;, score=0.823 total time=  12.9s
# [CV 2/3] END max_depth=50, min_samples_leaf=2, min_samples_split=4, n_estimators=200;, score=0.828 total time=  11.0s
# [CV 3/3] END max_depth=50, min_samples_leaf=2, min_samples_split=4, n_estimators=200;, score=0.823 total time=  13.7s
# [CV 1/3] END max_depth=50, min_samples_leaf=2, min_samples_split=6, n_estimators=100;, score=0.816 total time=   5.2s
# [CV 2/3] END max_depth=50, min_samples_leaf=2, min_samples_split=6, n_estimators=100;, score=0.820 total time=   8.6s
# [CV 3/3] END max_depth=50, min_samples_leaf=2, min_samples_split=6, n_estimators=100;, score=0.819 total time=   5.0s
# [CV 1/3] END max_depth=50, min_samples_leaf=2, min_samples_split=6, n_estimators=150;, score=0.817 total time=  10.4s
# [CV 2/3] END max_depth=50, min_samples_leaf=2, min_samples_split=6, n_estimators=150;, score=0.822 total time=   8.2s
# [CV 3/3] END max_depth=50, min_samples_leaf=2, min_samples_split=6, n_estimators=150;, score=0.819 total time=  11.0s
# [CV 1/3] END max_depth=50, min_samples_leaf=2, min_samples_split=6, n_estimators=200;, score=0.816 total time=  10.2s
# [CV 2/3] END max_depth=50, min_samples_leaf=2, min_samples_split=6, n_estimators=200;, score=0.824 total time=  13.6s
# [CV 3/3] END max_depth=50, min_samples_leaf=2, min_samples_split=6, n_estimators=200;, score=0.820 total time=  13.6s
# [CV 1/3] END max_depth=50, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.804 total time=   4.8s
# [CV 2/3] END max_depth=50, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.809 total time=   5.5s
# [CV 3/3] END max_depth=50, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.804 total time=   7.5s
# [CV 1/3] END max_depth=50, min_samples_leaf=4, min_samples_split=2, n_estimators=150;, score=0.805 total time=   7.1s
# [CV 2/3] END max_depth=50, min_samples_leaf=4, min_samples_split=2, n_estimators=150;, score=0.808 total time=  10.7s
# [CV 3/3] END max_depth=50, min_samples_leaf=4, min_samples_split=2, n_estimators=150;, score=0.808 total time=   7.2s
# [CV 1/3] END max_depth=50, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=0.804 total time=  16.2s
# [CV 2/3] END max_depth=50, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=0.809 total time=  13.3s
# [CV 3/3] END max_depth=50, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=0.807 total time=   9.5s
# [CV 1/3] END max_depth=50, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.804 total time=   8.2s
# [CV 2/3] END max_depth=50, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.809 total time=   4.8s
# [CV 3/3] END max_depth=50, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.804 total time=   4.8s
# [CV 1/3] END max_depth=50, min_samples_leaf=4, min_samples_split=4, n_estimators=150;, score=0.805 total time=  10.7s
# [CV 2/3] END max_depth=50, min_samples_leaf=4, min_samples_split=4, n_estimators=150;, score=0.808 total time=   7.2s
# [CV 3/3] END max_depth=50, min_samples_leaf=4, min_samples_split=4, n_estimators=150;, score=0.808 total time=  10.6s
# [CV 1/3] END max_depth=50, min_samples_leaf=4, min_samples_split=4, n_estimators=200;, score=0.804 total time=  11.0s
# [CV 2/3] END max_depth=50, min_samples_leaf=4, min_samples_split=4, n_estimators=200;, score=0.809 total time=  11.4s
# [CV 3/3] END max_depth=50, min_samples_leaf=4, min_samples_split=4, n_estimators=200;, score=0.807 total time=  13.0s
# [CV 1/3] END max_depth=50, min_samples_leaf=4, min_samples_split=6, n_estimators=100;, score=0.804 total time=   4.7s
# [CV 2/3] END max_depth=50, min_samples_leaf=4, min_samples_split=6, n_estimators=100;, score=0.809 total time=   6.1s
# [CV 3/3] END max_depth=50, min_samples_leaf=4, min_samples_split=6, n_estimators=100;, score=0.804 total time=   6.8s
# [CV 1/3] END max_depth=50, min_samples_leaf=4, min_samples_split=6, n_estimators=150;, score=0.805 total time=   7.1s
# [CV 2/3] END max_depth=50, min_samples_leaf=4, min_samples_split=6, n_estimators=150;, score=0.808 total time=  10.7s
# [CV 3/3] END max_depth=50, min_samples_leaf=4, min_samples_split=6, n_estimators=150;, score=0.808 total time=   7.1s
# [CV 1/3] END max_depth=50, min_samples_leaf=4, min_samples_split=6, n_estimators=200;, score=0.804 total time=  13.0s
# [CV 2/3] END max_depth=50, min_samples_leaf=4, min_samples_split=6, n_estimators=200;, score=0.809 total time=  12.6s
# [CV 3/3] END max_depth=50, min_samples_leaf=4, min_samples_split=6, n_estimators=200;, score=0.807 total time=   9.8s
# [CV 1/3] END max_depth=50, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.786 total time=   7.5s
# [CV 2/3] END max_depth=50, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.792 total time=   5.1s
# [CV 3/3] END max_depth=50, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.790 total time=   4.5s
# [CV 1/3] END max_depth=50, min_samples_leaf=6, min_samples_split=2, n_estimators=150;, score=0.789 total time=  10.3s
# [CV 2/3] END max_depth=50, min_samples_leaf=6, min_samples_split=2, n_estimators=150;, score=0.793 total time=   6.8s
# [CV 3/3] END max_depth=50, min_samples_leaf=6, min_samples_split=2, n_estimators=150;, score=0.793 total time=  10.3s
# [CV 1/3] END max_depth=50, min_samples_leaf=6, min_samples_split=2, n_estimators=200;, score=0.789 total time=   9.1s
# [CV 2/3] END max_depth=50, min_samples_leaf=6, min_samples_split=2, n_estimators=200;, score=0.792 total time=  12.6s
# [CV 3/3] END max_depth=50, min_samples_leaf=6, min_samples_split=2, n_estimators=200;, score=0.794 total time=  11.3s
# [CV 1/3] END max_depth=50, min_samples_leaf=6, min_samples_split=4, n_estimators=100;, score=0.786 total time=   5.8s
# [CV 2/3] END max_depth=50, min_samples_leaf=6, min_samples_split=4, n_estimators=100;, score=0.792 total time=   4.6s
# [CV 3/3] END max_depth=50, min_samples_leaf=6, min_samples_split=4, n_estimators=100;, score=0.790 total time=   6.3s
# [CV 1/3] END max_depth=50, min_samples_leaf=6, min_samples_split=4, n_estimators=150;, score=0.789 total time=   8.6s
# [CV 2/3] END max_depth=50, min_samples_leaf=6, min_samples_split=4, n_estimators=150;, score=0.793 total time=   8.0s
# [CV 3/3] END max_depth=50, min_samples_leaf=6, min_samples_split=4, n_estimators=150;, score=0.793 total time=   9.1s
# [CV 1/3] END max_depth=50, min_samples_leaf=6, min_samples_split=4, n_estimators=200;, score=0.789 total time=  11.5s
# [CV 2/3] END max_depth=50, min_samples_leaf=6, min_samples_split=4, n_estimators=200;, score=0.792 total time=  10.1s
# [CV 3/3] END max_depth=50, min_samples_leaf=6, min_samples_split=4, n_estimators=200;, score=0.794 total time=  12.6s
# [CV 1/3] END max_depth=50, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.786 total time=   4.6s
# [CV 2/3] END max_depth=50, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.792 total time=   6.1s
# [CV 3/3] END max_depth=50, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.790 total time=   6.5s
# [CV 1/3] END max_depth=50, min_samples_leaf=6, min_samples_split=6, n_estimators=150;, score=0.789 total time=   6.8s
# [CV 2/3] END max_depth=50, min_samples_leaf=6, min_samples_split=6, n_estimators=150;, score=0.793 total time=  12.8s
# [CV 3/3] END max_depth=50, min_samples_leaf=6, min_samples_split=6, n_estimators=150;, score=0.793 total time=   8.1s
# [CV 1/3] END max_depth=50, min_samples_leaf=6, min_samples_split=6, n_estimators=200;, score=0.789 total time=  12.6s
# [CV 2/3] END max_depth=50, min_samples_leaf=6, min_samples_split=6, n_estimators=200;, score=0.792 total time=   9.0s
# [CV 3/3] END max_depth=50, min_samples_leaf=6, min_samples_split=6, n_estimators=200;, score=0.794 total time=  12.6s
# [CV 1/3] END max_depth=70, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.831 total time=   5.5s
# [CV 2/3] END max_depth=70, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.836 total time=   8.9s
# [CV 3/3] END max_depth=70, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.828 total time=   5.5s
# [CV 1/3] END max_depth=70, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.831 total time=  11.6s
# [CV 2/3] END max_depth=70, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.834 total time=   8.2s
# [CV 3/3] END max_depth=70, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.827 total time=  11.7s
# [CV 1/3] END max_depth=70, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.831 total time=  13.3s
# [CV 2/3] END max_depth=70, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.834 total time=  12.0s
# [CV 3/3] END max_depth=70, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.829 total time=  14.3s
# [CV 1/3] END max_depth=70, min_samples_leaf=1, min_samples_split=4, n_estimators=100;, score=0.827 total time=   6.4s
# [CV 2/3] END max_depth=70, min_samples_leaf=1, min_samples_split=4, n_estimators=100;, score=0.831 total time=   7.7s
# [CV 3/3] END max_depth=70, min_samples_leaf=1, min_samples_split=4, n_estimators=100;, score=0.828 total time=   5.3s
# [CV 1/3] END max_depth=70, min_samples_leaf=1, min_samples_split=4, n_estimators=150;, score=0.827 total time=  11.5s
# [CV 2/3] END max_depth=70, min_samples_leaf=1, min_samples_split=4, n_estimators=150;, score=0.834 total time=   8.0s
# [CV 3/3] END max_depth=70, min_samples_leaf=1, min_samples_split=4, n_estimators=150;, score=0.828 total time=  11.4s
# [CV 1/3] END max_depth=70, min_samples_leaf=1, min_samples_split=4, n_estimators=200;, score=0.826 total time=  13.1s
# [CV 2/3] END max_depth=70, min_samples_leaf=1, min_samples_split=4, n_estimators=200;, score=0.833 total time=  11.4s
# [CV 3/3] END max_depth=70, min_samples_leaf=1, min_samples_split=4, n_estimators=200;, score=0.829 total time=  14.1s
# [CV 1/3] END max_depth=70, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.820 total time=   5.5s
# [CV 2/3] END max_depth=70, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.828 total time=   8.3s
# [CV 3/3] END max_depth=70, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.820 total time=   5.2s
# [CV 1/3] END max_depth=70, min_samples_leaf=1, min_samples_split=6, n_estimators=150;, score=0.820 total time=  11.2s
# [CV 2/3] END max_depth=70, min_samples_leaf=1, min_samples_split=6, n_estimators=150;, score=0.826 total time=   7.8s
# [CV 3/3] END max_depth=70, min_samples_leaf=1, min_samples_split=6, n_estimators=150;, score=0.823 total time=  11.3s
# [CV 1/3] END max_depth=70, min_samples_leaf=1, min_samples_split=6, n_estimators=200;, score=0.822 total time=  11.4s
# [CV 2/3] END max_depth=70, min_samples_leaf=1, min_samples_split=6, n_estimators=200;, score=0.827 total time=  12.6s
# [CV 3/3] END max_depth=70, min_samples_leaf=1, min_samples_split=6, n_estimators=200;, score=0.825 total time=  13.9s
# [CV 1/3] END max_depth=70, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.821 total time=   5.1s
# [CV 2/3] END max_depth=70, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.829 total time=   8.0s
# [CV 3/3] END max_depth=70, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.822 total time=   5.7s
# [CV 1/3] END max_depth=70, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=0.822 total time=   9.2s
# [CV 2/3] END max_depth=70, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=0.828 total time=   9.7s
# [CV 3/3] END max_depth=70, min_samples_leaf=2, min_samples_split=2, n_estimators=150;, score=0.822 total time=  10.1s
# [CV 1/3] END max_depth=70, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.823 total time=  16.5s
# [CV 2/3] END max_depth=70, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.828 total time=  11.9s
# [CV 3/3] END max_depth=70, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.823 total time=  13.8s
# [CV 1/3] END max_depth=70, min_samples_leaf=2, min_samples_split=4, n_estimators=100;, score=0.821 total time=   5.1s
# [CV 2/3] END max_depth=70, min_samples_leaf=2, min_samples_split=4, n_estimators=100;, score=0.829 total time=   8.5s
# [CV 3/3] END max_depth=70, min_samples_leaf=2, min_samples_split=4, n_estimators=100;, score=0.822 total time=   5.2s
# [CV 1/3] END max_depth=70, min_samples_leaf=2, min_samples_split=4, n_estimators=150;, score=0.822 total time=   9.8s
# [CV 2/3] END max_depth=70, min_samples_leaf=2, min_samples_split=4, n_estimators=150;, score=0.828 total time=   9.0s
# [CV 3/3] END max_depth=70, min_samples_leaf=2, min_samples_split=4, n_estimators=150;, score=0.822 total time=  10.8s
# [CV 1/3] END max_depth=70, min_samples_leaf=2, min_samples_split=4, n_estimators=200;, score=0.823 total time=  10.4s
# [CV 2/3] END max_depth=70, min_samples_leaf=2, min_samples_split=4, n_estimators=200;, score=0.828 total time=  13.7s
# [CV 3/3] END max_depth=70, min_samples_leaf=2, min_samples_split=4, n_estimators=200;, score=0.823 total time=  13.7s
# [CV 1/3] END max_depth=70, min_samples_leaf=2, min_samples_split=6, n_estimators=100;, score=0.816 total time=   5.1s
# [CV 2/3] END max_depth=70, min_samples_leaf=2, min_samples_split=6, n_estimators=100;, score=0.820 total time=   5.9s
# [CV 3/3] END max_depth=70, min_samples_leaf=2, min_samples_split=6, n_estimators=100;, score=0.819 total time=   7.6s
# [CV 1/3] END max_depth=70, min_samples_leaf=2, min_samples_split=6, n_estimators=150;, score=0.817 total time=   7.7s
# [CV 2/3] END max_depth=70, min_samples_leaf=2, min_samples_split=6, n_estimators=150;, score=0.822 total time=  11.1s
# [CV 3/3] END max_depth=70, min_samples_leaf=2, min_samples_split=6, n_estimators=150;, score=0.819 total time=   7.7s
# [CV 1/3] END max_depth=70, min_samples_leaf=2, min_samples_split=6, n_estimators=200;, score=0.816 total time=  13.4s
# [CV 2/3] END max_depth=70, min_samples_leaf=2, min_samples_split=6, n_estimators=200;, score=0.824 total time=  13.6s
# [CV 3/3] END max_depth=70, min_samples_leaf=2, min_samples_split=6, n_estimators=200;, score=0.820 total time=  11.2s
# [CV 1/3] END max_depth=70, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.804 total time=   6.9s
# [CV 2/3] END max_depth=70, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.809 total time=   4.8s
# [CV 3/3] END max_depth=70, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.804 total time=   5.7s
# [CV 1/3] END max_depth=70, min_samples_leaf=4, min_samples_split=2, n_estimators=150;, score=0.805 total time=   9.6s
# [CV 2/3] END max_depth=70, min_samples_leaf=4, min_samples_split=2, n_estimators=150;, score=0.808 total time=   8.1s
# [CV 3/3] END max_depth=70, min_samples_leaf=4, min_samples_split=2, n_estimators=150;, score=0.808 total time=   9.6s
# [CV 1/3] END max_depth=70, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=0.804 total time=  12.3s
# [CV 2/3] END max_depth=70, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=0.809 total time=  10.0s
# [CV 3/3] END max_depth=70, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=0.807 total time=  12.9s
# [CV 1/3] END max_depth=70, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.804 total time=   4.7s
# [CV 2/3] END max_depth=70, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.809 total time=   7.4s
# [CV 3/3] END max_depth=70, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.804 total time=   5.6s
# [CV 1/3] END max_depth=70, min_samples_leaf=4, min_samples_split=4, n_estimators=150;, score=0.805 total time=   7.6s
# [CV 2/3] END max_depth=70, min_samples_leaf=4, min_samples_split=4, n_estimators=150;, score=0.808 total time=  10.1s
# [CV 3/3] END max_depth=70, min_samples_leaf=4, min_samples_split=4, n_estimators=150;, score=0.808 total time=   7.4s
# [CV 1/3] END max_depth=70, min_samples_leaf=4, min_samples_split=4, n_estimators=200;, score=0.804 total time=  12.7s
# [CV 2/3] END max_depth=70, min_samples_leaf=4, min_samples_split=4, n_estimators=200;, score=0.809 total time=  13.1s
# [CV 3/3] END max_depth=70, min_samples_leaf=4, min_samples_split=4, n_estimators=200;, score=0.807 total time=   9.6s
# [CV 1/3] END max_depth=70, min_samples_leaf=4, min_samples_split=6, n_estimators=100;, score=0.804 total time=   9.1s
# [CV 2/3] END max_depth=70, min_samples_leaf=4, min_samples_split=6, n_estimators=100;, score=0.809 total time=   7.3s
# [CV 3/3] END max_depth=70, min_samples_leaf=4, min_samples_split=6, n_estimators=100;, score=0.804 total time=   6.6s
# [CV 1/3] END max_depth=70, min_samples_leaf=4, min_samples_split=6, n_estimators=150;, score=0.805 total time=   8.7s
# [CV 2/3] END max_depth=70, min_samples_leaf=4, min_samples_split=6, n_estimators=150;, score=0.808 total time=   8.8s
# [CV 3/3] END max_depth=70, min_samples_leaf=4, min_samples_split=6, n_estimators=150;, score=0.808 total time=   8.9s
# [CV 1/3] END max_depth=70, min_samples_leaf=4, min_samples_split=6, n_estimators=200;, score=0.804 total time=  12.9s
# [CV 2/3] END max_depth=70, min_samples_leaf=4, min_samples_split=6, n_estimators=200;, score=0.809 total time=   9.5s
# [CV 3/3] END max_depth=70, min_samples_leaf=4, min_samples_split=6, n_estimators=200;, score=0.807 total time=  12.9s
# [CV 1/3] END max_depth=70, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.786 total time=   4.5s
# [CV 2/3] END max_depth=70, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.792 total time=   7.9s
# [CV 3/3] END max_depth=70, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.790 total time=   4.7s
# [CV 1/3] END max_depth=70, min_samples_leaf=6, min_samples_split=2, n_estimators=150;, score=0.789 total time=   7.7s
# [CV 2/3] END max_depth=70, min_samples_leaf=6, min_samples_split=2, n_estimators=150;, score=0.793 total time=   9.4s
# [CV 3/3] END max_depth=70, min_samples_leaf=6, min_samples_split=2, n_estimators=150;, score=0.793 total time=   7.2s
# [CV 1/3] END max_depth=70, min_samples_leaf=6, min_samples_split=2, n_estimators=200;, score=0.789 total time=  12.1s
# [CV 2/3] END max_depth=70, min_samples_leaf=6, min_samples_split=2, n_estimators=200;, score=0.792 total time=  12.5s
# [CV 3/3] END max_depth=70, min_samples_leaf=6, min_samples_split=2, n_estimators=200;, score=0.794 total time=   9.0s
# [CV 1/3] END max_depth=70, min_samples_leaf=6, min_samples_split=4, n_estimators=100;, score=0.786 total time=   7.4s
# [CV 2/3] END max_depth=70, min_samples_leaf=6, min_samples_split=4, n_estimators=100;, score=0.792 total time=   5.2s
# [CV 3/3] END max_depth=70, min_samples_leaf=6, min_samples_split=4, n_estimators=100;, score=0.790 total time=   4.6s
# [CV 1/3] END max_depth=70, min_samples_leaf=6, min_samples_split=4, n_estimators=150;, score=0.789 total time=  10.3s
# [CV 2/3] END max_depth=70, min_samples_leaf=6, min_samples_split=4, n_estimators=150;, score=0.793 total time=   6.9s
# [CV 3/3] END max_depth=70, min_samples_leaf=6, min_samples_split=4, n_estimators=150;, score=0.793 total time=  10.3s
# [CV 1/3] END max_depth=70, min_samples_leaf=6, min_samples_split=4, n_estimators=200;, score=0.789 total time=   9.1s
# [CV 2/3] END max_depth=70, min_samples_leaf=6, min_samples_split=4, n_estimators=200;, score=0.792 total time=  12.6s
# [CV 3/3] END max_depth=70, min_samples_leaf=6, min_samples_split=4, n_estimators=200;, score=0.794 total time=  11.3s
# [CV 1/3] END max_depth=70, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.786 total time=   5.7s
# [CV 2/3] END max_depth=70, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.792 total time=   4.6s
# [CV 3/3] END max_depth=70, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.790 total time=   6.2s
# [CV 1/3] END max_depth=70, min_samples_leaf=6, min_samples_split=6, n_estimators=150;, score=0.789 total time=   8.6s
# [CV 2/3] END max_depth=70, min_samples_leaf=6, min_samples_split=6, n_estimators=150;, score=0.793 total time=   8.2s
# [CV 3/3] END max_depth=70, min_samples_leaf=6, min_samples_split=6, n_estimators=150;, score=0.793 total time=   8.9s
# [CV 1/3] END max_depth=70, min_samples_leaf=6, min_samples_split=6, n_estimators=200;, score=0.789 total time=  11.6s
# [CV 2/3] END max_depth=70, min_samples_leaf=6, min_samples_split=6, n_estimators=200;, score=0.792 total time=   9.9s
# [CV 3/3] END max_depth=70, min_samples_leaf=6, min_samples_split=6, n_estimators=200;, score=0.794 total time=  12.6s
# 최적 하이퍼 파라미터:  {'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}

# %%
# 위의 결과로 나온 최적 하이퍼 파라미터로 테스트 세트 데이터에서 예측 성능을 측정
print('예측 정확도: {:.4f}'.format(grid.best_score_))
y_pred = grid.predict(X_test)

print('test 정확도: {:.4f}'.format(accuracy_score(y_test,y_pred)))
print('오차 행렬')
print(confusion_matrix( y_test, y_pred))
print(classification_report(y_test, y_pred))
#TPR=
#FPR=
#BDR=(TPR*0.65)/(TPR*0.65+FPR*0.35)
#print("BDR:", BDR )
# Out:
# 예측 정확도: 0.8315
# test 정확도: 0.8474
# 오차 행렬
# [[2967    0    0 ...    0    0    0]
#  [   0   38    0 ...    0    0    0]
#  [   0    0   36 ...    0    0    0]
#  ...
#  [   0    0    0 ...   36    0    0]
#  [   0    0    0 ...    0   55    0]
#  [   0    2    0 ...    0    0   35]]
#               precision    recall  f1-score   support
#
#           -1       1.00      1.00      1.00      2967
#            0       0.73      0.61      0.67        62
#            1       0.84      0.55      0.67        65
#            2       0.83      0.85      0.84        62
#            3       0.81      0.83      0.82        63
#            4       0.73      0.78      0.75        67
#            5       0.90      0.83      0.86        52
#            6       0.87      0.89      0.88        65
#            7       0.74      0.87      0.80        61
#            8       0.69      0.91      0.79        57
#            9       0.77      0.83      0.79        75
#           10       0.81      0.74      0.77        62
#           11       0.72      0.57      0.64        51
#           12       0.91      0.96      0.93        70
#           13       0.60      0.45      0.51        56
#           14       0.67      0.62      0.65        66
#           15       0.83      0.84      0.83        62
#           16       0.80      0.72      0.76        65
#           17       0.64      0.75      0.69        48
#           18       0.78      0.88      0.82        56
#           19       0.85      0.84      0.84        61
#           20       0.81      0.92      0.86        61
#           21       0.66      0.58      0.62        64
#           22       0.69      0.60      0.64        67
#           23       0.70      0.91      0.79        58
#           24       0.50      0.35      0.41        65
#           25       0.89      0.83      0.86        66
#           26       0.81      0.92      0.86        52
#           27       0.88      0.75      0.81        59
#           28       0.87      0.78      0.82        69
#           29       0.75      0.74      0.75        66
#           30       0.81      0.81      0.81        69
#           31       0.65      0.79      0.72        43
#           32       0.77      0.64      0.70        58
#           33       0.82      0.64      0.72        70
#           34       0.78      0.51      0.61        75
#           35       0.74      0.91      0.81        55
#           36       0.81      0.93      0.87        56
#           37       0.70      0.53      0.60        59
#           38       0.62      0.85      0.72        52
#           39       0.86      0.77      0.81        57
#           40       0.74      0.79      0.76        63
#           41       0.82      0.94      0.88        67
#           42       0.66      0.66      0.66        71
#           43       0.80      0.81      0.80        63
#           44       0.93      0.93      0.93        58
#           45       0.71      0.67      0.69        52
#           46       0.77      0.75      0.76        61
#           47       0.76      0.81      0.78        62
#           48       0.82      0.73      0.77        49
#           49       0.84      0.89      0.86        54
#           50       0.76      0.80      0.78        56
#           51       0.57      0.64      0.60        61
#           52       0.77      0.85      0.81        60
#           53       0.70      0.84      0.76        62
#           54       0.87      0.87      0.87        67
#           55       0.54      0.64      0.58        59
#           56       0.88      0.98      0.93        47
#           57       0.80      0.71      0.75        72
#           58       0.90      0.86      0.88        63
#           59       0.85      0.90      0.88        59
#           60       0.80      0.82      0.81        62
#           61       0.71      0.80      0.75        50
#           62       0.72      0.79      0.75        62
#           63       0.61      0.72      0.66        61
#           64       0.70      0.71      0.71        56
#           65       0.83      0.74      0.78        54
#           66       0.80      0.78      0.79        65
#           67       0.78      0.76      0.77        59
#           68       0.82      0.70      0.75        66
#           69       0.78      0.72      0.75        65
#           70       0.93      0.96      0.94        69
#           71       0.74      0.73      0.73        62
#           72       0.79      0.78      0.78        67
#           73       0.95      0.95      0.95        58
#           74       0.67      0.66      0.66        79
#           75       0.90      0.90      0.90        61
#           76       0.90      0.90      0.90        63
#           77       0.58      0.62      0.60        55
#           78       0.56      0.69      0.62        54
#           79       0.63      0.79      0.70        48
#           80       0.86      0.84      0.85        61
#           81       0.77      0.74      0.75        68
#           82       0.74      0.62      0.67        55
#           83       0.86      0.86      0.86        59
#           84       0.79      0.68      0.73        50
#           85       0.81      0.85      0.83        54
#           86       0.86      0.96      0.91        67
#           87       0.73      0.83      0.77        58
#           88       0.83      0.70      0.76        50
#           89       0.70      0.62      0.66        65
#           90       0.68      0.70      0.69        57
#           91       0.88      0.69      0.77        62
#           92       0.68      0.69      0.69        52
#           93       0.93      0.92      0.92        60
#           94       0.62      0.76      0.69        46
#
#     accuracy                           0.85      8700
#    macro avg       0.77      0.77      0.77      8700
# weighted avg       0.85      0.85      0.85      8700

# %%
# feature names 뽑기(header 제외)
a=multi.drop(['y'], axis=1)
column_headers=list(a.columns.values)

# %%
# 5. Report the feature rankings with importance scores using the bar plot using barplot provided by seaborn library.

import seaborn as sns
import matplotlib.pyplot as plt


feature_imp = pd.Series(grid.best_estimator_.feature_importances_, index=column_headers).sort_values(ascending=False)

plt.figure(figsize=(10,6))
sns.barplot(x=feature_imp, y=feature_imp.index)
# Add labels to your graph
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
plt.tight_layout()
